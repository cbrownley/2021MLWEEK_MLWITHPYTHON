# %% [markdown]
# <a id="top"></a>

# %% [markdown]
# # Credit Card Fraud (Classification)

# %% [markdown]
# # Outline
#
# - [Read Data](#read_data)
# - [Create target and features](#create_y_and_X)
# - [Split data into train and test](#train_test_split)
# - [View descriptive statistics](#descriptive_statistics)
# - [View target and feature distributions](#distributions)
# - [View correlations](#correlations)
# - [View relationships between target and features](#pair_plots)
# - [Standardize predictors](#standardize_predictors)
# - [Predictive models](#predictive_models)
# - [Logistic regression](#logistic_regression)
# - [K-nearest neighbors](#k_nearest_neighbors)
# - [Linear discriminant analysis](#linear_discriminant_analysis)
# - [Support vector machines](#support_vector_machines)
# - [Random Forest](#random_forest)
# - [Compare models](#compare_models)
# - [Oversampling](#oversampling)
# - [Statsmodels](#statsmodels)

# %% [markdown]
# # Import packages

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
from time import time
from pprint import pprint

from IPython.display import Image
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="white")

import statsmodels.api as sm
import statsmodels.formula.api as smf

from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import classification_report, plot_roc_curve, plot_confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score
from sklearn.metrics import f1_score, cohen_kappa_score, precision_recall_fscore_support

from sklearn.dummy import DummyClassifier
from sklearn.linear_model import LogisticRegressionCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.inspection import permutation_importance

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <a id="read_data"></a>

# %% [markdown]
# # [Read data](https://www.tensorflow.org/tutorials/structured_data/imbalanced_data)

# %%
Image(filename='../images/credit_card_fraud_dataset_description.png', width=1000)

# %%
Image(filename='../images/credit_card_fraud_dataset_recommended_evaluation_metric.png', width=1000)

# %%
infile = '../data/credit_card_fraud.csv'

# %%
df = pd.read_csv(infile)

['{}: {}'.format(i, name) for (i, name) in enumerate(list(df.columns))]
# Out:
# ['0: class',
#  '1: v1',
#  '2: v2',
#  '3: v3',
#  '4: v4',
#  '5: v5',
#  '6: v6',
#  '7: v7',
#  '8: v8',
#  '9: v9',
#  '10: v10',
#  '11: v11',
#  '12: v12',
#  '13: v13',
#  '14: v14',
#  '15: v15',
#  '16: v16',
#  '17: v17',
#  '18: v18',
#  '19: v19',
#  '20: v20',
#  '21: v21',
#  '22: v22',
#  '23: v23',
#  '24: v24',
#  '25: v25',
#  '26: v26',
#  '27: v27',
#  '28: v28',
#  '29: log_amount']

# %%
df.head(10)
# Out:
#    class        v1        v2        v3        v4        v5        v6  \
# 0      0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1      0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2      0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3      0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4      0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# 5      0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728
# 6      0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708
# 7      0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118
# 8      0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818
# 9      0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761
#
#          v7        v8        v9  ...       v20       v21       v22       v23  \
# 0  0.239599  0.098698  0.363787  ...  0.251412 -0.018307  0.277838 -0.110474
# 1 -0.078803  0.085102 -0.255425  ... -0.069083 -0.225775 -0.638672  0.101288
# 2  0.791461  0.247676 -1.514654  ...  0.524980  0.247998  0.771679  0.909412
# 3  0.237609  0.377436 -1.387024  ... -0.208038 -0.108300  0.005274 -0.190321
# 4  0.592941 -0.270533  0.817739  ...  0.408542 -0.009431  0.798278 -0.137458
# 5  0.476201  0.260314 -0.568671  ...  0.084968 -0.208254 -0.559825 -0.026398
# 6 -0.005159  0.081213  0.464960  ... -0.219633 -0.167716 -0.270710 -0.154104
# 7  1.120631 -3.807864  0.615375  ... -0.156742  1.943465 -1.015455  0.057504
# 8  0.370145  0.851084 -0.392048  ...  0.052736 -0.073425 -0.268092 -0.204233
# 9  0.651583  0.069539 -0.736727  ...  0.203711 -0.246914 -0.633753 -0.120794
#
#         v24       v25       v26       v27       v28  log_amount
# 0  0.066928  0.128539 -0.189115  0.133558 -0.021053    5.008105
# 1 -0.339846  0.167170  0.125895 -0.008983  0.014724    0.989913
# 2 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752    5.936641
# 3 -1.175575  0.647376 -0.221929  0.062723  0.061458    4.816249
# 4  0.141267 -0.206010  0.502292  0.219422  0.215153    4.248367
# 5 -0.371427 -0.232794  0.105915  0.253844  0.081080    1.300464
# 6 -0.780055  0.750137 -0.257237  0.034507  0.005168    1.607636
# 7 -0.649709 -0.415267 -0.051634 -1.206921 -1.085339    3.708707
# 8  1.011592  0.373205 -0.384157  0.011747  0.142404    4.534758
# 9 -0.385050 -0.069733  0.094199  0.246219  0.083076    1.303184
#
# [10 rows x 30 columns]

# %%
df.shape
# Out:
# (284807, 30)

# %%
pd.concat([df['class'].value_counts(), 
           df['class'].value_counts(normalize=True).round(5)], axis=1)
# Out:
#     class    class
# 0  284315  0.99827
# 1     492  0.00173

# %% [markdown]
# # Downsample to reduce model fitting time

# %%
y0_downsampled = df.loc[df['class'] == 0, :].sample(frac=0.05, replace=False, random_state=1)
y1_downsampled = df.loc[df['class'] == 1, :].sample(frac=0.05, replace=False, random_state=1)

# %%
df_downsampled = pd.concat([y0_downsampled, y1_downsampled], axis=0)

# %%
pd.concat([df_downsampled['class'].value_counts(), 
           df_downsampled['class'].value_counts(normalize=True).round(5)], axis=1)
# Out:
#    class    class
# 0  14216  0.99824
# 1     25  0.00176

# %% [markdown]
# <a id="create_y_and_X"></a>

# %% [markdown]
# # Create target, y, and predictor, X, variables

# %%
neg, pos = np.bincount(df_downsampled['class'])
total = neg + pos
print('Examples:\n    Total: {}\n    Positive: {} ({:.3f}% of total)\n'.format(
    total, pos, 100 * pos / total))
# Out:
# Examples:
#     Total: 14241
#     Positive: 25 (0.176% of total)

# %%
X = df_downsampled.iloc[:, 1:].values
y = df_downsampled['class'].values.astype(int)

y_labels = ['Not Fraud', 'Fraud']

print('Class labels:', np.unique(y), y_labels, [(i, val) for (i, val) in enumerate(np.bincount(y))])
# Out:
# Class labels: [0 1] ['Not Fraud', 'Fraud'] [(0, 14216), (1, 25)]

# %% [markdown]
# <a id="train_test_split"></a>

# %% [markdown]
# # Split data into train and test sets

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=1, stratify=y)

# %%
X_train
# Out:
# array([[-0.08269851,  0.94647664, -0.95405519, ..., -0.03486101,
#          0.03945203,  4.21436214],
#        [-1.32416099, -0.53624985,  0.84293343, ..., -0.03793072,
#         -0.1785678 ,  5.43677846],
#        [-0.73154399,  1.32884249,  1.29509562, ...,  0.0459347 ,
#          0.1365257 ,  3.60307644],
#        ...,
#        [ 1.74604528, -1.62079938,  0.20883578, ...,  0.06399062,
#          0.00804578,  5.11560173],
#        [-3.81603381, -1.49266164, -1.46735804, ..., -0.63973237,
#          0.02706764,  5.50338248],
#        [-0.44796771,  1.02319169, -0.15177005, ..., -0.9975166 ,
#         -0.55423174,  0.25541711]])

# %%
print('Labels counts in y:',       np.bincount(y),       
      [round(cnt / np.sum(np.bincount(y)) * 100, 1) for cnt in np.bincount(y)])

print('Labels counts in y_train:', np.bincount(y_train), 
      [round(cnt / np.sum(np.bincount(y_train)) * 100, 1) for cnt in np.bincount(y_train)])

print('Labels counts in y_test:',  np.bincount(y_test),  
      [round(cnt / np.sum(np.bincount(y_test)) * 100, 1) for cnt in np.bincount(y_test)])
# Out:
# Labels counts in y: [14216    25] [99.8, 0.2]
# Labels counts in y_train: [9951   17] [99.8, 0.2]
# Labels counts in y_test: [4265    8] [99.8, 0.2]

# %% [markdown]
# <a id="descriptive_statistics"></a>

# %% [markdown]
# # View descriptive statistics

# %%
data = pd.DataFrame(np.hstack((y_train.reshape(-1,1), X_train)), 
                    columns=list(df.columns))

data.describe().T.round(2)
# Out:
#              count  mean   std    min   25%   50%   75%    max
# class       9968.0  0.00  0.04   0.00  0.00  0.00  0.00   1.00
# v1          9968.0 -0.02  1.97 -30.82 -0.90 -0.01  1.30   2.45
# v2          9968.0 -0.01  1.71 -35.62 -0.59  0.07  0.81  14.85
# v3          9968.0  0.00  1.53 -27.75 -0.85  0.18  1.02   4.02
# v4          9968.0  0.01  1.44  -4.84 -0.85 -0.01  0.77  11.19
# v5          9968.0 -0.00  1.45 -28.36 -0.70 -0.05  0.61  22.71
# v6          9968.0 -0.01  1.34 -13.36 -0.77 -0.29  0.39  17.02
# v7          9968.0  0.01  1.31 -23.19 -0.54  0.05  0.59  30.90
# v8          9968.0 -0.02  1.33 -37.35 -0.21  0.02  0.31  17.57
# v9          9968.0 -0.00  1.09  -8.63 -0.64 -0.06  0.59  10.39
# v10         9968.0 -0.02  1.06 -16.26 -0.55 -0.11  0.45  12.26
# v11         9968.0 -0.01  1.02  -4.45 -0.77 -0.05  0.73  10.45
# v12         9968.0 -0.01  0.99 -15.48 -0.40  0.13  0.62   4.40
# v13         9968.0  0.01  1.00  -3.96 -0.64 -0.01  0.67   3.49
# v14         9968.0  0.01  0.94 -13.88 -0.43  0.05  0.49   7.44
# v15         9968.0 -0.02  0.92  -3.92 -0.60  0.04  0.64   3.88
# v16         9968.0 -0.01  0.86 -11.91 -0.48  0.06  0.51   4.46
# v17         9968.0  0.01  0.83 -18.10 -0.48 -0.05  0.41   7.14
# v18         9968.0  0.01  0.83  -7.15 -0.48 -0.00  0.51   3.67
# v19         9968.0  0.00  0.81  -3.75 -0.46  0.00  0.46   4.60
# v20         9968.0  0.01  0.76 -19.35 -0.21 -0.06  0.14  15.27
# v21         9968.0  0.00  0.81 -13.92 -0.23 -0.02  0.19  27.20
# v22         9968.0  0.00  0.73  -8.89 -0.54  0.02  0.53   4.53
# v23         9968.0  0.01  0.66 -12.35 -0.16 -0.01  0.15  18.36
# v24         9968.0  0.00  0.60  -2.77 -0.35  0.04  0.44   3.57
# v25         9968.0  0.00  0.52  -3.76 -0.32  0.02  0.36   5.47
# v26         9968.0 -0.00  0.48  -1.73 -0.33 -0.06  0.24   2.83
# v27         9968.0  0.00  0.38  -9.54 -0.07  0.00  0.09   8.09
# v28         9968.0 -0.00  0.31  -5.31 -0.05  0.01  0.08  15.87
# log_amount  9968.0  2.98  2.00  -6.91  1.79  3.12  4.34   8.93

# %% [markdown]
# <a id="distributions"></a>

# %% [markdown]
# # View target distribution

# %%
plt.subplots(figsize=(8,6))
sns.histplot(data['class'], kde=False);

# %% [markdown]
# # View predictor distributions by target category

# %%
f, axs = plt.subplots(15, 2, figsize=(20,70))

for i, feat in enumerate(X_train.T):
    sns.histplot(feat[y_train==0], ax=axs.flat[i], color='steelblue', stat='density', common_norm=False, kde=True, label='{}: {}'.format('Not Fraud', len(y_train[y_train==0])))
    sns.histplot(feat[y_train==1], ax=axs.flat[i], color='orange',    stat='density', common_norm=False, kde=True, label='{}: {}'.format('Fraud',     len(y_train[y_train==1])))
    axs.flat[i].set_title('{}:  mean: {}  std: {}'.format(list(data.columns)[i+1], abs(feat.mean().round(2)), feat.std().round(2)))
    axs.flat[i].legend()
plt.tight_layout();

# %% [markdown]
# <a id="correlations"></a>

# %% [markdown]
# # View predictor correlations

# %%
plt.figure(figsize=(30, 30))

matrix = np.triu(data.corr())
sns.heatmap(data.corr(), 
            annot=True, fmt='.2g', 
            mask=matrix, 
            vmin=-1, vmax=1, center=0, 
            cmap=sns.diverging_palette(20, 220, n=100));

# %% [markdown]
# <a id="pair_plots"></a>

# %% [markdown]
# # Visualize distributions of, and relationships between, target and predictors

# %%
sns.pairplot(data.iloc[:, :7], 
             vars=list(data.columns)[:7], 
             kind='reg',
             diag_kind='hist',
             hue='class', 
             # markers=['o', 's'], 
             corner=True,  
             plot_kws={'scatter_kws': {'alpha': 0.05}, 
                       'x_jitter': 0.1, 'y_jitter': 0.1});

# %%
sns.pairplot(pd.concat([data.iloc[:, 0], data.iloc[:, 8:15]], axis=1), 
             vars=[list(data.columns)[0]]+list(data.columns)[8:15], 
             kind='reg',
             diag_kind='hist',
             hue='class', 
             corner=True,  
             plot_kws={'scatter_kws': {'alpha': 0.05}, 
                       'x_jitter': 0.1, 'y_jitter': 0.1});

# %%
sns.pairplot(pd.concat([data.iloc[:, 0], data.iloc[:, 15:23]], axis=1), 
             vars=[list(data.columns)[0]]+list(data.columns)[15:23], 
             kind='reg',
             diag_kind='hist',
             hue='class', 
             corner=True,  
             plot_kws={'scatter_kws': {'alpha': 0.05}, 
                       'x_jitter': 0.1, 'y_jitter': 0.1});

# %%
sns.pairplot(pd.concat([data.iloc[:, 0], data.iloc[:, 23:]], axis=1), 
             vars=[list(data.columns)[0]]+list(data.columns)[23:], 
             kind='reg',
             diag_kind='hist',
             hue='class', 
             corner=True,  
             plot_kws={'scatter_kws': {'alpha': 0.05}, 
                       'x_jitter': 0.1, 'y_jitter': 0.1});

# %% [markdown]
# <a id="standardize_predictors"></a>

# %% [markdown]
# # [Standardize](https://scikit-learn.org/stable/modules/preprocessing.html) the Predictors

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std  = sc.transform(X_test)

# %% [markdown]
# # View standardized predictor distributions by target category

# %%
f, axs = plt.subplots(15, 2, figsize=(20,70))

for i, feat in enumerate(X_train_std.T):
    sns.histplot(feat[y_train==0], ax=axs.flat[i], color='steelblue', stat='density', common_norm=False, kde=True, label='{}: {}'.format('Not Fraud', len(y_train[y_train==0])))
    sns.histplot(feat[y_train==1], ax=axs.flat[i], color='orange',    stat='density', common_norm=False, kde=True, label='{}: {}'.format('Fraud',     len(y_train[y_train==1])))
    axs.flat[i].set_title('{}:  mean: {}  std: {}'.format(list(data.columns)[i+1], abs(feat.mean().round(2)), feat.std().round(2)))
    axs.flat[i].legend()
plt.tight_layout();

# %% [markdown]
# <a id="predictive_models"></a>

# %% [markdown]
# # Predictive Models

# %% [markdown]
# # [DummyClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.dummy.DummyClassifier.html) estimator

# %%
from sklearn.dummy import DummyClassifier

d_clf = DummyClassifier(strategy='constant', constant=0)
d_clf.fit(X_train_std, y_train)

print('Accuracy (train): {:.3f}'.format(d_clf.score(X_train_std, y_train)))
print('Accuracy  (test): {:.3f}'.format(d_clf.score(X_test_std,  y_test)))
# Out:
# Accuracy (train): 0.998
# Accuracy  (test): 0.998

# %% [markdown]
# # [Confusion matrix](https://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html)

# %%
from sklearn.metrics import plot_confusion_matrix

f, ax = plt.subplots(figsize=(6,6))
plot_confusion_matrix(d_clf, X_test_std, y_test, 
                      ax=ax,
                      display_labels=y_labels, 
                      cmap=plt.cm.Blues, 
                      values_format='d', # for float: '.2g'
                      normalize=None);

# %% [markdown]
# # [Classification report](https://scikit-learn.org/stable/modules/model_evaluation.html#classification-report)

# %%
from sklearn.metrics import classification_report

y_pred = d_clf.predict(X_test_std)

print(classification_report(y_test, y_pred, 
                            target_names=y_labels))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00      4265
#        Fraud       0.00      0.00      0.00         8
#
#     accuracy                           1.00      4273
#    macro avg       0.50      0.50      0.50      4273
# weighted avg       1.00      1.00      1.00      4273

# %% [markdown]
# # [ROC curve](https://scikit-learn.org/stable/auto_examples/plot_roc_curve_visualization_api.html)

# %%
from sklearn.metrics import plot_roc_curve

f, ax = plt.subplots(figsize=(8,6))
plot_roc_curve(d_clf, X_test_std, y_test, ax=ax, color='orange');

# %% [markdown]
# <a id="logistic_regression"></a>

# %% [markdown]
# # [Logistic Regression](https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression)

# %%
from sklearn.linear_model import LogisticRegressionCV

# Cs: Each of the values in Cs describes the inverse of regularization strength

# L1 Ratio: A value of 0 is equivalent to using penalty='l2'
#           A value of 1 is equivalent to using penalty='l1'
#           For 0 < l1_ratio <1, the penalty is a combination of L1 and L2
lr_clf = LogisticRegressionCV(cv=3, 
                              penalty='elasticnet', solver='saga', 
                              Cs=np.power(10, np.arange(-3, 1, dtype=float)), 
                              l1_ratios=np.linspace(0, 1, num=6, dtype=float), 
                              max_iter=1000, 
                              random_state=0, 
                              n_jobs=3)

start = time()
lr_clf.fit(X_train_std, y_train)
lr_duration = time() - start

print("LogisticRegressionCV took {:.2f} seconds for {} cv iterations with {} parameter settings.".format(lr_duration, 
                                                                                                         lr_clf.n_iter_.shape[1], 
                                                                                                         lr_clf.n_iter_.shape[2] * lr_clf.n_iter_.shape[3]))

print('Optimal regularization strength: {}  Optimal L1 Ratio: {}'.format(lr_clf.C_[0], lr_clf.l1_ratio_[0]))
print('Accuracy (train): {:.2f}'.format(lr_clf.score(X_train_std, y_train)))
print('Accuracy  (test): {:.2f}'.format(lr_clf.score(X_test_std,  y_test)))
# Out:
# LogisticRegressionCV took 72.66 seconds for 3 cv iterations with 24 parameter settings.
# Optimal regularization strength: 1.0  Optimal L1 Ratio: 0.0
# Accuracy (train): 1.00
# Accuracy  (test): 1.00

# %% [markdown]
# ## Model parameters

# %%
lr_params = dict(zip(list(data.columns)[1:], list(lr_clf.coef_[0])), 
                 intercept=lr_clf.intercept_[0])
{param: value.round(2) for (param, value) in sorted(lr_params.items(), key=lambda item: item[1], reverse=True)}
# Out:
# {'v1': 0.89,
#  'v4': 0.75,
#  'v5': 0.51,
#  'v28': 0.39,
#  'v27': 0.31,
#  'v24': 0.22,
#  'v22': 0.21,
#  'v23': 0.11,
#  'v13': 0.1,
#  'v20': 0.08,
#  'v11': 0.05,
#  'v21': 0.03,
#  'v16': 0.0,
#  'v26': -0.01,
#  'v18': -0.04,
#  'v2': -0.1,
#  'v3': -0.1,
#  'v10': -0.18,
#  'v25': -0.19,
#  'v7': -0.31,
#  'v6': -0.31,
#  'v12': -0.36,
#  'log_amount': -0.38,
#  'v8': -0.39,
#  'v15': -0.42,
#  'v19': -0.45,
#  'v9': -0.5,
#  'v17': -0.56,
#  'v14': -1.06,
#  'intercept': -9.76}

# %% [markdown]
# ## Predicted class labels

# %%
predicted_class_labels = lr_clf.predict(X_test_std)
predicted_class_labels
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %% [markdown]
# ## Predicted probabilities of class labels

# %%
predicted_class_probabilities = lr_clf.predict_proba(X_test_std)
[dict(zip(['Not Fraud(0)', 'Fraud(1)'], map(lambda val: val.round(3), list(arr))), obs_id=i) 
 for (i, arr) in enumerate(list(predicted_class_probabilities))]
# Out:
# [{'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 0},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 1},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 2},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 3},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 4},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 5},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 6},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 7},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 8},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 9},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 10},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 11},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 12},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 13},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 14},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 15},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 16},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 17},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 18},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 19},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 20},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 21},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 22},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 23},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 24},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 25},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 26},
#  {'Not Fraud(0)': 0.993, 'Fraud(1)': 0.007, 'obs_id': 27},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 28},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 29},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 30},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 31},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 32},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 33},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 34},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 35},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 36},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 37},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 38},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 39},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 40},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 41},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 42},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 43},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 44},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 45},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 46},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 47},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 48},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 49},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 50},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 51},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 52},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 53},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 54},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 55},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 56},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 57},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 58},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 59},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 60},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 61},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 62},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 63},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 64},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 65},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 66},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 67},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 68},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 69},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 70},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 71},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 72},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 73},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 74},
#  {'Not Fraud(0)': 0.987, 'Fraud(1)': 0.013, 'obs_id': 75},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 76},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 77},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 78},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 79},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 80},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 81},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 82},
#  {'Not Fraud(0)': 0.992, 'Fraud(1)': 0.008, 'obs_id': 83},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 84},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 85},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 86},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 87},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 88},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 89},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 90},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 91},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 92},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 93},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 94},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 95},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 96},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 97},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 98},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 99},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 100},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 101},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 102},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 103},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 104},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 105},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 106},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 107},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 108},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 109},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 110},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 111},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 112},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 113},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 114},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 115},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 116},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 117},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 118},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 119},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 120},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 121},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 122},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 123},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 124},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 125},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 126},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 127},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 128},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 129},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 130},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 131},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 132},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 133},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 134},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 135},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 136},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 137},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 138},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 139},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 140},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 141},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 142},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 143},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 144},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 145},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 146},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 147},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 148},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 149},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 150},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 151},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 152},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 153},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 154},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 155},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 156},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 157},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 158},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 159},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 160},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 161},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 162},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 163},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 164},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 165},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 166},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 167},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 168},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 169},
#  {'Not Fraud(0)': 0.996, 'Fraud(1)': 0.004, 'obs_id': 170},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 171},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 172},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 173},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 174},
#  {'Not Fraud(0)': 0.995, 'Fraud(1)': 0.005, 'obs_id': 175},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 176},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 177},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 178},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 179},
#  {'Not Fraud(0)': 0.998, 'Fraud(1)': 0.002, 'obs_id': 180},
#  {'Not Fraud(0)': 0.993, 'Fraud(1)': 0.007, 'obs_id': 181},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 182},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 183},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 184},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 185},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 186},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 187},
#  {'Not Fraud(0)': 0.998, 'Fraud(1)': 0.002, 'obs_id': 188},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 189},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 190},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 191},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 192},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 193},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 194},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 195},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 196},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 197},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 198},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 199},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 200},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 201},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 202},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 203},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 204},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 205},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 206},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 207},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 208},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 209},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 210},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 211},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 212},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 213},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 214},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 215},
#  {'Not Fraud(0)': 0.996, 'Fraud(1)': 0.004, 'obs_id': 216},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 217},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 218},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 219},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 220},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 221},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 222},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 223},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 224},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 225},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 226},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 227},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 228},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 229},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 230},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 231},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 232},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 233},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 234},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 235},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 236},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 237},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 238},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 239},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 240},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 241},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 242},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 243},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 244},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 245},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 246},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 247},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 248},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 249},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 250},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 251},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 252},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 253},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 254},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 255},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 256},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 257},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 258},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 259},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 260},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 261},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 262},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 263},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 264},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 265},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 266},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 267},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 268},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 269},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 270},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 271},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 272},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 273},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 274},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 275},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 276},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 277},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 278},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 279},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 280},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 281},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 282},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 283},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 284},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 285},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 286},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 287},
#  {'Not Fraud(0)': 0.998, 'Fraud(1)': 0.002, 'obs_id': 288},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 289},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 290},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 291},
#  {'Not Fraud(0)': 0.033, 'Fraud(1)': 0.967, 'obs_id': 292},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 293},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 294},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 295},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 296},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 297},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 298},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 299},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 300},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 301},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 302},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 303},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 304},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 305},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 306},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 307},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 308},
#  {'Not Fraud(0)': 0.998, 'Fraud(1)': 0.002, 'obs_id': 309},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 310},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 311},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 312},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 313},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 314},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 315},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 316},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 317},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 318},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 319},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 320},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 321},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 322},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 323},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 324},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 325},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 326},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 327},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 328},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 329},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 330},
#  {'Not Fraud(0)': 0.983, 'Fraud(1)': 0.017, 'obs_id': 331},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 332},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 333},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 334},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 335},
#  {'Not Fraud(0)': 0.997, 'Fraud(1)': 0.003, 'obs_id': 336},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 337},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 338},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 339},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 340},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 341},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 342},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 343},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 344},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 345},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 346},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 347},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 348},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 349},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 350},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 351},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 352},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 353},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 354},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 355},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 356},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 357},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 358},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 359},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 360},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 361},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 362},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 363},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 364},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 365},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 366},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 367},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 368},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 369},
#  {'Not Fraud(0)': 0.998, 'Fraud(1)': 0.002, 'obs_id': 370},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 371},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 372},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 373},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 374},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 375},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 376},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 377},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 378},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 379},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 380},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 381},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 382},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 383},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 384},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 385},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 386},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 387},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 388},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 389},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 390},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 391},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 392},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 393},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 394},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 395},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 396},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 397},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 398},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 399},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 400},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 401},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 402},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 403},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 404},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 405},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 406},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 407},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 408},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 409},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 410},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 411},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 412},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 413},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 414},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 415},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 416},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 417},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 418},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 419},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 420},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 421},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 422},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 423},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 424},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 425},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 426},
#  {'Not Fraud(0)': 0.992, 'Fraud(1)': 0.008, 'obs_id': 427},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 428},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 429},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 430},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 431},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 432},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 433},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 434},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 435},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 436},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 437},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 438},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 439},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 440},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 441},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 442},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 443},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 444},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 445},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 446},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 447},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 448},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 449},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 450},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 451},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 452},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 453},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 454},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 455},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 456},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 457},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 458},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 459},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 460},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 461},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 462},
#  {'Not Fraud(0)': 0.995, 'Fraud(1)': 0.005, 'obs_id': 463},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 464},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 465},
#  {'Not Fraud(0)': 0.928, 'Fraud(1)': 0.072, 'obs_id': 466},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 467},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 468},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 469},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 470},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 471},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 472},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 473},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 474},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 475},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 476},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 477},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 478},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 479},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 480},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 481},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 482},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 483},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 484},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 485},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 486},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 487},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 488},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 489},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 490},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 491},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 492},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 493},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 494},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 495},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 496},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 497},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 498},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 499},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 500},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 501},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 502},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 503},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 504},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 505},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 506},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 507},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 508},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 509},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 510},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 511},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 512},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 513},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 514},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 515},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 516},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 517},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 518},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 519},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 520},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 521},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 522},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 523},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 524},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 525},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 526},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 527},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 528},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 529},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 530},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 531},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 532},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 533},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 534},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 535},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 536},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 537},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 538},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 539},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 540},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 541},
#  {'Not Fraud(0)': 0.0, 'Fraud(1)': 1.0, 'obs_id': 542},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 543},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 544},
#  {'Not Fraud(0)': 0.996, 'Fraud(1)': 0.004, 'obs_id': 545},
#  {'Not Fraud(0)': 0.997, 'Fraud(1)': 0.003, 'obs_id': 546},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 547},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 548},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 549},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 550},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 551},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 552},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 553},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 554},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 555},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 556},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 557},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 558},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 559},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 560},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 561},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 562},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 563},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 564},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 565},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 566},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 567},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 568},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 569},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 570},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 571},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 572},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 573},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 574},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 575},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 576},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 577},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 578},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 579},
#  {'Not Fraud(0)': 0.998, 'Fraud(1)': 0.002, 'obs_id': 580},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 581},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 582},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 583},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 584},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 585},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 586},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 587},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 588},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 589},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 590},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 591},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 592},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 593},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 594},
#  {'Not Fraud(0)': 0.95, 'Fraud(1)': 0.05, 'obs_id': 595},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 596},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 597},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 598},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 599},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 600},
#  {'Not Fraud(0)': 0.862, 'Fraud(1)': 0.138, 'obs_id': 601},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 602},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 603},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 604},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 605},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 606},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 607},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 608},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 609},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 610},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 611},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 612},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 613},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 614},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 615},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 616},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 617},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 618},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 619},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 620},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 621},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 622},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 623},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 624},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 625},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 626},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 627},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 628},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 629},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 630},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 631},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 632},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 633},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 634},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 635},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 636},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 637},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 638},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 639},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 640},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 641},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 642},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 643},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 644},
#  {'Not Fraud(0)': 0.985, 'Fraud(1)': 0.015, 'obs_id': 645},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 646},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 647},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 648},
#  {'Not Fraud(0)': 0.996, 'Fraud(1)': 0.004, 'obs_id': 649},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 650},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 651},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 652},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 653},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 654},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 655},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 656},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 657},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 658},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 659},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 660},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 661},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 662},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 663},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 664},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 665},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 666},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 667},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 668},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 669},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 670},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 671},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 672},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 673},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 674},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 675},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 676},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 677},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 678},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 679},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 680},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 681},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 682},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 683},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 684},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 685},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 686},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 687},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 688},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 689},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 690},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 691},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 692},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 693},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 694},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 695},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 696},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 697},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 698},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 699},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 700},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 701},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 702},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 703},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 704},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 705},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 706},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 707},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 708},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 709},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 710},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 711},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 712},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 713},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 714},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 715},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 716},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 717},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 718},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 719},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 720},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 721},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 722},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 723},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 724},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 725},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 726},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 727},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 728},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 729},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 730},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 731},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 732},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 733},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 734},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 735},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 736},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 737},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 738},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 739},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 740},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 741},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 742},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 743},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 744},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 745},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 746},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 747},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 748},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 749},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 750},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 751},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 752},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 753},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 754},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 755},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 756},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 757},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 758},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 759},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 760},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 761},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 762},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 763},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 764},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 765},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 766},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 767},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 768},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 769},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 770},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 771},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 772},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 773},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 774},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 775},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 776},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 777},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 778},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 779},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 780},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 781},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 782},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 783},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 784},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 785},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 786},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 787},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 788},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 789},
#  {'Not Fraud(0)': 0.997, 'Fraud(1)': 0.003, 'obs_id': 790},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 791},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 792},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 793},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 794},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 795},
#  {'Not Fraud(0)': 0.997, 'Fraud(1)': 0.003, 'obs_id': 796},
#  {'Not Fraud(0)': 0.998, 'Fraud(1)': 0.002, 'obs_id': 797},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 798},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 799},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 800},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 801},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 802},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 803},
#  {'Not Fraud(0)': 0.997, 'Fraud(1)': 0.003, 'obs_id': 804},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 805},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 806},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 807},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 808},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 809},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 810},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 811},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 812},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 813},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 814},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 815},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 816},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 817},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 818},
#  {'Not Fraud(0)': 0.996, 'Fraud(1)': 0.004, 'obs_id': 819},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 820},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 821},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 822},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 823},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 824},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 825},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 826},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 827},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 828},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 829},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 830},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 831},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 832},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 833},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 834},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 835},
#  {'Not Fraud(0)': 0.997, 'Fraud(1)': 0.003, 'obs_id': 836},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 837},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 838},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 839},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 840},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 841},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 842},
#  {'Not Fraud(0)': 0.997, 'Fraud(1)': 0.003, 'obs_id': 843},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 844},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 845},
#  {'Not Fraud(0)': 0.997, 'Fraud(1)': 0.003, 'obs_id': 846},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 847},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 848},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 849},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 850},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 851},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 852},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 853},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 854},
#  {'Not Fraud(0)': 0.998, 'Fraud(1)': 0.002, 'obs_id': 855},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 856},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 857},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 858},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 859},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 860},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 861},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 862},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 863},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 864},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 865},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 866},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 867},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 868},
#  {'Not Fraud(0)': 0.998, 'Fraud(1)': 0.002, 'obs_id': 869},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 870},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 871},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 872},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 873},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 874},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 875},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 876},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 877},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 878},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 879},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 880},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 881},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 882},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 883},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 884},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 885},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 886},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 887},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 888},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 889},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 890},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 891},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 892},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 893},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 894},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 895},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 896},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 897},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 898},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 899},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 900},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 901},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 902},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 903},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 904},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 905},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 906},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 907},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 908},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 909},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 910},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 911},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 912},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 913},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 914},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 915},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 916},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 917},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 918},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 919},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 920},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 921},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 922},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 923},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 924},
#  {'Not Fraud(0)': 0.984, 'Fraud(1)': 0.016, 'obs_id': 925},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 926},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 927},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 928},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 929},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 930},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 931},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 932},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 933},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 934},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 935},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 936},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 937},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 938},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 939},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 940},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 941},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 942},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 943},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 944},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 945},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 946},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 947},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 948},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 949},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 950},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 951},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 952},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 953},
#  {'Not Fraud(0)': 0.997, 'Fraud(1)': 0.003, 'obs_id': 954},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 955},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 956},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 957},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 958},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 959},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 960},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 961},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 962},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 963},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 964},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 965},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 966},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 967},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 968},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 969},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 970},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 971},
#  {'Not Fraud(0)': 0.996, 'Fraud(1)': 0.004, 'obs_id': 972},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 973},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 974},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 975},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 976},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 977},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 978},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 979},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 980},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 981},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 982},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 983},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 984},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 985},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 986},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 987},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 988},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 989},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 990},
#  {'Not Fraud(0)': 0.999, 'Fraud(1)': 0.001, 'obs_id': 991},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 992},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 993},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 994},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 995},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 996},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 997},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 998},
#  {'Not Fraud(0)': 1.0, 'Fraud(1)': 0.0, 'obs_id': 999},
#  ...]

# %% [markdown]
# ## Cross-validation score on test set

# %%
from sklearn.model_selection import cross_val_score

def get_cross_val(clf, X, y, model_name, cv_num=5, metric='f1'):
    scores = cross_val_score(clf, X, y, cv=cv_num, scoring=metric)
    mean = scores.mean()
    std  = scores.std()
    p025 = np.quantile(scores, 0.025)
    p975 = np.quantile(scores, 0.975)
    metrics = ['mean', 'standard deviation', 'p025', 'p975']
    s = pd.Series([mean, std, p025, p975], index=metrics)  # np.where(lb < 0, 0, lb), np.where(ub > 1, 1, ub)
    s.name = model_name
    return s

# %%
lr_cv = get_cross_val(lr_clf, X_test_std, y_test, 'logistic regression')
lr_cv.round(2)
# Out:
# mean                  0.53
# standard deviation    0.28
# p025                  0.05
# p975                  0.79
# Name: logistic regression, dtype: float64

# %% [markdown]
# ## Confusion matrix

# %%
f, ax = plt.subplots(figsize=(6,6))
plot_confusion_matrix(lr_clf, X_test_std, y_test, 
                      ax=ax,
                      display_labels=y_labels, 
                      cmap=plt.cm.Blues, 
                      values_format='d', # '.2g'
                      normalize=None);

# %% [markdown]
# ## Classification report

# %%
y_pred = lr_clf.predict(X_test_std)

print(classification_report(y_test, y_pred, 
                            target_names=y_labels))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00      4265
#        Fraud       1.00      0.62      0.77         8
#
#     accuracy                           1.00      4273
#    macro avg       1.00      0.81      0.88      4273
# weighted avg       1.00      1.00      1.00      4273

# %% [markdown]
# ## A collection of metrics for comparing models

# %%
def calculate_metrics(y_true, y_pred, duration, model_name, *args):
    acc     = accuracy_score(y_true, y_pred)
    pre     = precision_score(y_true, y_pred)
    rec     = recall_score(y_true, y_pred)
    roc_auc = roc_auc_score(y_true, y_pred)
    f1      = f1_score(y_true, y_pred)
    ck      = cohen_kappa_score(y_true, y_pred)
    p, r, fbeta, support = precision_recall_fscore_support(y_true, y_pred)
    metrics = ['accuracy', 'precision', 'recall', 'roc_auc', 'f1_score', 'cohen_kappa',  
               'precision_both', 'recall_both', 'fbeta_both', 'support_both', 'time_to_fit (seconds)']
    s = pd.Series([acc, pre, rec, roc_auc, f1, ck, p, r, fbeta, support, duration], index=metrics)
    s.name = model_name
    return s

# %%
lr_metrics = calculate_metrics(y_test, y_pred, lr_duration, 'logistic_regression')
lr_metrics
# Out:
# accuracy                                                 0.999298
# precision                                                       1
# recall                                                      0.625
# roc_auc                                                    0.8125
# f1_score                                                 0.769231
# cohen_kappa                                              0.768898
# precision_both                          [0.9992970946579194, 1.0]
# recall_both                                          [1.0, 0.625]
# fbeta_both               [0.9996484237665534, 0.7692307692307693]
# support_both                                            [4265, 8]
# time_to_fit (seconds)                                     103.912
# Name: logistic_regression, dtype: object

# %% [markdown]
# ## ROC curve

# %%
f, ax = plt.subplots(figsize=(8,6))
plot_roc_curve(lr_clf, X_test_std, y_test, ax=ax, color='blue');

# %% [markdown]
# <a id="k_nearest_neighbors"></a>

# %% [markdown]
# # K-Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier

param_grid = {'weights': ['uniform', 'distance'],
              'n_neighbors': np.arange(1,16)}

knn_clf = KNeighborsClassifier()

gs_knn = GridSearchCV(knn_clf, param_grid=param_grid)

start = time()
gs_knn.fit(X_train_std, y_train)
knn_duration = time() - start

print("GridSearchCV of KNN took {:.2f} seconds for {} candidate parameter settings.".format(knn_duration, 
                                                                                            len(gs_knn.cv_results_['params'])))
# report(gs_knn.cv_results_)
print('Optimal weights: {}  Optimal n_neighbors: {}'.format(gs_knn.best_params_['weights'], gs_knn.best_params_['n_neighbors']))
print('Accuracy (train): {:.2f}'.format(gs_knn.score(X_train_std, y_train)))
print('Accuracy  (test): {:.2f}'.format(gs_knn.score(X_test_std,  y_test)))
# Out:
# GridSearchCV of KNN took 160.73 seconds for 30 candidate parameter settings.
# Optimal weights: distance  Optimal n_neighbors: 7
# Accuracy (train): 1.00
# Accuracy  (test): 1.00

# %% [markdown]
# ## Best parameters

# %%
pprint(gs_knn.best_estimator_.get_params())
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 7,
#  'p': 2,
#  'weights': 'distance'}

# %% [markdown]
# ## Cross-validation score on test set

# %%
knn_cv = get_cross_val(gs_knn, X_test_std, y_test, 'k-nearest neighbors')
knn_cv.round(2)
# Out:
# mean                  0.73
# standard deviation    0.39
# p025                  0.07
# p975                  1.00
# Name: k-nearest neighbors, dtype: float64

# %% [markdown]
# ## Confusion matrix

# %%
f, ax = plt.subplots(figsize=(6,6))
plot_confusion_matrix(gs_knn, X_test_std, y_test, 
                      ax=ax,
                      display_labels=y_labels, 
                      cmap=plt.cm.Blues, 
                      values_format='d', # '.2g'
                      normalize=None);

# %% [markdown]
# ## Classification report

# %%
y_pred = gs_knn.predict(X_test_std)

print(classification_report(y_test, y_pred, 
                            target_names=y_labels))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00      4265
#        Fraud       1.00      0.62      0.77         8
#
#     accuracy                           1.00      4273
#    macro avg       1.00      0.81      0.88      4273
# weighted avg       1.00      1.00      1.00      4273

# %% [markdown]
# ## A collection of metrics for comparing models

# %%
knn_metrics = calculate_metrics(y_test, y_pred, knn_duration, 'k-nearest neighbors')
knn_metrics
# Out:
# accuracy                                                 0.999298
# precision                                                       1
# recall                                                      0.625
# roc_auc                                                    0.8125
# f1_score                                                 0.769231
# cohen_kappa                                              0.768898
# precision_both                          [0.9992970946579194, 1.0]
# recall_both                                          [1.0, 0.625]
# fbeta_both               [0.9996484237665534, 0.7692307692307693]
# support_both                                            [4265, 8]
# time_to_fit (seconds)                                     160.731
# Name: k-nearest neighbors, dtype: object

# %% [markdown]
# ## ROC curve

# %%
f, ax = plt.subplots(figsize=(8,6))
plot_roc_curve(gs_knn, X_test_std, y_test, ax=ax, color='blue');

# %% [markdown]
# <a id="linear_discriminant_analysis"></a>

# %% [markdown]
# # Linear Discriminant Analysis

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

param_grid = {'solver': ['lsqr', 'eigen'],
              'shrinkage': [None, 'auto'], 
              'n_components': np.arange(1,5)}

lda_clf = LinearDiscriminantAnalysis()

gs_lda = GridSearchCV(lda_clf, param_grid=param_grid)

start = time()
gs_lda.fit(X_train_std, y_train)
lda_duration = time() - start

print("GridSearchCV of LDA took {:.2f} seconds for {} candidate parameter settings.".format(lda_duration, 
                                                                                            len(gs_lda.cv_results_['params'])))
# report(gs_lda.cv_results_)
print('Optimal solver: {}  Optimal shrinkage: {}  Optimal n_components: {}'.format(gs_lda.best_params_['solver'], gs_lda.best_params_['shrinkage'], gs_lda.best_params_['n_components']))
print('Accuracy (train): {:.2f}'.format(gs_lda.score(X_train_std, y_train)))
print('Accuracy  (test): {:.2f}'.format(gs_lda.score(X_test_std,  y_test)))
# Out:
# GridSearchCV of LDA took 2.88 seconds for 16 candidate parameter settings.
# Optimal solver: lsqr  Optimal shrinkage: None  Optimal n_components: 1
# Accuracy (train): 1.00
# Accuracy  (test): 1.00

# %% [markdown]
# ## Cross-validation score on test set

# %%
lda_cv = get_cross_val(lda_clf, X_test_std, y_test, 'linear discriminanat analysis')
lda_cv.round(2)
# Out:
# mean                  0.76
# standard deviation    0.13
# p025                  0.67
# p975                  0.98
# Name: linear discriminanat analysis, dtype: float64

# %% [markdown]
# ## Confusion matrix

# %%
f, ax = plt.subplots(figsize=(6,6))
plot_confusion_matrix(gs_lda, X_test_std, y_test, 
                      ax=ax,
                      display_labels=y_labels, 
                      cmap=plt.cm.Blues, 
                      values_format='d', # '.2g'
                      normalize=None);

# %% [markdown]
# ## Classification report

# %%
y_pred = gs_lda.predict(X_test_std)

print(classification_report(y_test, y_pred, 
                            target_names=y_labels))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00      4265
#        Fraud       1.00      0.75      0.86         8
#
#     accuracy                           1.00      4273
#    macro avg       1.00      0.88      0.93      4273
# weighted avg       1.00      1.00      1.00      4273

# %% [markdown]
# ## A collection of metrics for comparing models

# %%
lda_metrics = calculate_metrics(y_test, y_pred, lda_duration, 'linear discriminant analysis')
lda_metrics
# Out:
# accuracy                                                 0.999532
# precision                                                       1
# recall                                                       0.75
# roc_auc                                                     0.875
# f1_score                                                 0.857143
# cohen_kappa                                              0.856913
# precision_both                           [0.999531286618233, 1.0]
# recall_both                                           [1.0, 0.75]
# fbeta_both               [0.9997655883731834, 0.8571428571428571]
# support_both                                            [4265, 8]
# time_to_fit (seconds)                                     2.14943
# Name: linear discriminant analysis, dtype: object

# %% [markdown]
# ## ROC curve

# %%
f, ax = plt.subplots(figsize=(8,6))
plot_roc_curve(gs_lda, X_test_std, y_test, ax=ax, color='blue');

# %% [markdown]
# <a id="support_vector_machines"></a>

# %% [markdown]
# # Support Vector Machines

# %%
from sklearn.svm import SVC

param_grid = {'C': np.power(10, np.arange(0, 3, dtype=float)),
              'kernel': ['linear', 'sigmoid', 'rbf'], 
              'gamma': ['auto', 'scale']}

svc_clf = SVC(random_state=0)

gs_svc = GridSearchCV(svc_clf, param_grid=param_grid)

start = time()
gs_svc.fit(X_train_std, y_train)
svc_duration = time() - start

print("GridSearchCV of SVC took {:.2f} seconds for {} candidate parameter settings.".format(svc_duration, 
                                                                                            len(gs_svc.cv_results_['params'])))
# report(gs_svc.cv_results_)
print('Optimal C: {}  Optimal kernel: {}  Optimal gamma: {}'.format(gs_svc.best_params_['C'], gs_svc.best_params_['kernel'], gs_svc.best_params_['gamma']))
print('Accuracy (train): {:.2f}'.format(gs_svc.score(X_train_std, y_train)))
print('Accuracy  (test): {:.2f}'.format(gs_svc.score(X_test_std,  y_test)))
# Out:
# GridSearchCV of SVC took 7.23 seconds for 18 candidate parameter settings.
# Optimal C: 1.0  Optimal kernel: sigmoid  Optimal gamma: scale
# Accuracy (train): 1.00
# Accuracy  (test): 1.00

# %% [markdown]
# ## Cross-validation score on test set

# %%
svc_cv = get_cross_val(gs_svc, X_test_std, y_test, 'support vector machines')
svc_cv.round(2)
# Out:
# mean                  0.67
# standard deviation    0.37
# p025                  0.07
# p975                  1.00
# Name: support vector machines, dtype: float64

# %% [markdown]
# ## Confusion matrix

# %%
f, ax = plt.subplots(figsize=(6,6))
plot_confusion_matrix(gs_svc, X_test_std, y_test, 
                      ax=ax,
                      display_labels=y_labels, 
                      cmap=plt.cm.Blues, 
                      values_format='d', # '.2g'
                      normalize=None);

# %% [markdown]
# ## Classification report

# %%
y_pred = gs_svc.predict(X_test_std)

print(classification_report(y_test, y_pred, 
                            target_names=y_labels))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00      4265
#        Fraud       0.80      0.50      0.62         8
#
#     accuracy                           1.00      4273
#    macro avg       0.90      0.75      0.81      4273
# weighted avg       1.00      1.00      1.00      4273

# %% [markdown]
# ## A collection of metrics for comparing models

# %%
svc_metrics = calculate_metrics(y_test, y_pred, svc_duration, 'support vector machines')
svc_metrics
# Out:
# accuracy                                                  0.99883
# precision                                                     0.8
# recall                                                        0.5
# roc_auc                                                  0.749883
# f1_score                                                 0.615385
# cohen_kappa                                               0.61483
# precision_both                          [0.9990627928772259, 0.8]
# recall_both                             [0.9997655334114889, 0.5]
# fbeta_both               [0.9994140396109223, 0.6153846153846154]
# support_both                                            [4265, 8]
# time_to_fit (seconds)                                     5.91369
# Name: support vector machines, dtype: object

# %% [markdown]
# ## ROC curve

# %%
f, ax = plt.subplots(figsize=(8,6))
plot_roc_curve(gs_svc, X_test_std, y_test, ax=ax, color='blue');

# %% [markdown]
# <a id="random_forest"></a>

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

param_grid = {'n_estimators': np.arange(100, 1000, 200, dtype=int),
              'max_features': [None, 'sqrt', 'log2'],
              'max_depth': [None, 3, 5]}

rf_clf = RandomForestClassifier(oob_score=True, random_state=0)

gs_rf = GridSearchCV(rf_clf, param_grid=param_grid)

start = time()
gs_rf.fit(X_train_std, y_train)
rf_duration = time() - start

print("GridSearchCV of RF took {:.2f} seconds for {} candidate parameter settings.".format(rf_duration, 
                                                                                           len(gs_rf.cv_results_['params'])))
# report(gs_rf.cv_results_)
print('Optimal n_estimators: {}  Optimal max_features: {}  Optimal max_depth: {}'.format(gs_rf.best_params_['n_estimators'], 
                                                                                         gs_rf.best_params_['max_features'], 
                                                                                         gs_rf.best_params_['max_depth']))
print('Accuracy (train): {:.2f}'.format(gs_rf.score(X_train_std, y_train)))
print('Accuracy  (test): {:.2f}'.format(gs_rf.score(X_test_std,  y_test)))
# Out:
# GridSearchCV of RF took 2773.71 seconds for 45 candidate parameter settings.
# Optimal n_estimators: 100  Optimal max_features: sqrt  Optimal max_depth: None
# Accuracy (train): 1.00
# Accuracy  (test): 1.00

# %% [markdown]
# ## Cross-validation score on test set

# %%
clf_rf = RandomForestClassifier(n_estimators=gs_rf.best_params_['n_estimators'], 
                                max_features=gs_rf.best_params_['max_features'], 
                                max_depth=gs_rf.best_params_['max_depth'], 
                                oob_score=True, 
                                random_state=0)

rf_cv = get_cross_val(clf_rf, X_test_std, y_test, 'random forest')
rf_cv.round(2)
# Out:
# mean                  0.47
# standard deviation    0.40
# p025                  0.00
# p975                  0.97
# Name: random forest, dtype: float64

# %% [markdown]
# ## Confusion matrix

# %%
f, ax = plt.subplots(figsize=(6,6))
plot_confusion_matrix(gs_rf, X_test_std, y_test, 
                      ax=ax,
                      display_labels=y_labels, 
                      cmap=plt.cm.Blues, 
                      values_format='d', # '.2g'
                      normalize=None);

# %% [markdown]
# ## Classification report

# %%
y_pred = gs_rf.predict(X_test_std)

print(classification_report(y_test, y_pred, 
                            target_names=y_labels))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00      4265
#        Fraud       1.00      0.62      0.77         8
#
#     accuracy                           1.00      4273
#    macro avg       1.00      0.81      0.88      4273
# weighted avg       1.00      1.00      1.00      4273

# %% [markdown]
# ## A collection of metrics for comparing models

# %%
rf_metrics = calculate_metrics(y_test, y_pred, rf_duration, 'random forest')
rf_metrics
# Out:
# accuracy                                                 0.999298
# precision                                                       1
# recall                                                      0.625
# roc_auc                                                    0.8125
# f1_score                                                 0.769231
# cohen_kappa                                              0.768898
# precision_both                          [0.9992970946579194, 1.0]
# recall_both                                          [1.0, 0.625]
# fbeta_both               [0.9996484237665534, 0.7692307692307693]
# support_both                                            [4265, 8]
# time_to_fit (seconds)                                     2773.71
# Name: random forest, dtype: object

# %% [markdown]
# ## ROC curve

# %%
f, ax = plt.subplots(figsize=(8,6))
plot_roc_curve(gs_rf, X_test_std, y_test, ax=ax, color='blue');

# %% [markdown]
# ## Variable importances in the random forest model

# %%
from sklearn.inspection import permutation_importance

result = permutation_importance(gs_rf, X_test_std, y_test, n_repeats=10,
                                random_state=42, n_jobs=-1)
sorted_idx = result.importances_mean.argsort()

X_test_df = pd.DataFrame(X_test_std, columns=list(data.columns)[1:])

f, ax = plt.subplots(figsize=(8,16))
ax.boxplot(result.importances[sorted_idx].T,
           vert=False, labels=X_test_df.columns[sorted_idx])
ax.set_title("Permutation Importances (test set)")
plt.tight_layout();

# %% [markdown]
# <a id="compare_models"></a>

# %% [markdown]
# # Compare Models

# %% [markdown]
# ## Classification metrics scores and time-to-fit models (in seconds)

# %%
model_metrics = pd.concat([lr_metrics, knn_metrics, lda_metrics, svc_metrics, rf_metrics], axis=1).T

model_metrics.apply(lambda elem: [np.round(val, 2) for val in elem]).sort_values(by='f1_score', ascending=False)
# Out:
#                               accuracy  precision  recall  roc_auc  f1_score  \
# linear discriminant analysis       1.0        1.0    0.75     0.88      0.86
# logistic_regression                1.0        1.0    0.62     0.81      0.77
# k-nearest neighbors                1.0        1.0    0.62     0.81      0.77
# random forest                      1.0        1.0    0.62     0.81      0.77
# support vector machines            1.0        0.8    0.50     0.75      0.62
#
#                               cohen_kappa precision_both  recall_both  \
# linear discriminant analysis         0.86     [1.0, 1.0]  [1.0, 0.75]
# logistic_regression                  0.77     [1.0, 1.0]  [1.0, 0.62]
# k-nearest neighbors                  0.77     [1.0, 1.0]  [1.0, 0.62]
# random forest                        0.77     [1.0, 1.0]  [1.0, 0.62]
# support vector machines              0.61     [1.0, 0.8]   [1.0, 0.5]
#
#                                fbeta_both support_both  time_to_fit (seconds)
# linear discriminant analysis  [1.0, 0.86]    [4265, 8]                   2.15
# logistic_regression           [1.0, 0.77]    [4265, 8]                 103.91
# k-nearest neighbors           [1.0, 0.77]    [4265, 8]                 160.73
# random forest                 [1.0, 0.77]    [4265, 8]                2773.71
# support vector machines       [1.0, 0.62]    [4265, 8]                   5.91

# %% [markdown]
# ## Cross-validation scores on test set

# %%
cross_vals = pd.concat([lr_cv, knn_cv, lda_cv, svc_cv, rf_cv], axis=1).T

cross_vals = cross_vals.round(2).sort_values(by='mean', ascending=False)
cross_vals
# Out:
#                                mean  standard deviation  p025  p975
# linear discriminanat analysis  0.76                0.13  0.67  0.98
# k-nearest neighbors            0.73                0.39  0.07  1.00
# support vector machines        0.67                0.37  0.07  1.00
# logistic regression            0.53                0.28  0.05  0.79
# random forest                  0.47                0.40  0.00  0.97

# %% [markdown]
# ## Plot of mean (+/- std) cross-validation scores

# %%
fig = plt.figure(figsize=(8,6))

for i in range(len(cross_vals.index)):
    plt.errorbar(x=i, y=cross_vals.iloc[i, 0], # mean column
                 xerr=0.25,
                 yerr=cross_vals.iloc[i, 1], # standard deviation column   alternatively: [mean - p025, p975 - mean],
                 linestyle='',
                 label=list(cross_vals.index)[i])

#plt.ylim(0.7,1)
plt.title('Mean F1 Score (+/- 1 std) by Model,\nbased on 5-fold cross-validation on the test set')
plt.xlabel('Model')
plt.ylabel('F1 Score')
plt.legend(loc='lower left');

# %% [markdown]
# <a id="oversampling"></a>

# %% [markdown]
# # [Oversampling](https://github.com/scikit-learn-contrib/imbalanced-learn/wiki)

# %% [markdown]
# ## Using [NumPy](https://numpy.org/devdocs/)

# %%
bool_y_train = y_train != 0

pos_features = X_train_std[bool_y_train]
neg_features = X_train_std[~bool_y_train]

pos_labels = y_train[bool_y_train]
neg_labels = y_train[~bool_y_train]

pos_features.shape, neg_features.shape
# Out:
# ((17, 29), (9951, 29))

# %% [markdown]
# ## Oversample the minority class

# %%
ids = np.arange(len(pos_features))
choices = np.random.choice(ids, len(neg_features))

res_pos_features = pos_features[choices]
res_pos_labels   = pos_labels[choices]

res_pos_features.shape, res_pos_labels.shape
# Out:
# ((9951, 29), (9951,))

# %% [markdown]
# # Recombine oversampled minority class and majority class

# %%
resampled_features = np.concatenate([res_pos_features, neg_features], axis=0)
resampled_labels   = np.concatenate([res_pos_labels,   neg_labels],   axis=0)

order = np.arange(len(resampled_labels))
np.random.shuffle(order)

resampled_features = resampled_features[order]
resampled_labels   = resampled_labels[order]

resampled_features.shape, resampled_labels.shape
# Out:
# ((19902, 29), (19902,))

# %% [markdown]
# # Linear Discriminant Analysis

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

param_grid = {'solver': ['lsqr', 'eigen'],
              'shrinkage': [None, 'auto'], 
              'n_components': np.arange(1,5)}

lda_clf = LinearDiscriminantAnalysis()

gs_lda_resamp = GridSearchCV(lda_clf, param_grid=param_grid)

start = time()
gs_lda_resamp.fit(resampled_features, resampled_labels)
lda_duration = time() - start

print("GridSearchCV of LDA took {:.2f} seconds for {} candidate parameter settings.".format(lda_duration, 
                                                                                            len(gs_lda_resamp.cv_results_['params'])))
# report(gs_lda.cv_results_)
print('Optimal solver: {}  Optimal shrinkage: {}  Optimal n_components: {}'.format(gs_lda_resamp.best_params_['solver'], 
                                                                                   gs_lda_resamp.best_params_['shrinkage'], 
                                                                                   gs_lda_resamp.best_params_['n_components']))
print('Accuracy (train): {:.2f}'.format(gs_lda_resamp.score(resampled_features, resampled_labels)))
print('Accuracy  (test): {:.2f}'.format(gs_lda_resamp.score(X_test_std,  y_test)))
# Out:
# GridSearchCV of LDA took 6.39 seconds for 16 candidate parameter settings.
# Optimal solver: lsqr  Optimal shrinkage: auto  Optimal n_components: 1
# Accuracy (train): 0.99
# Accuracy  (test): 0.98

# %% [markdown]
# # Using [imbalanced-learn](https://imbalanced-learn.readthedocs.io/en/stable/over_sampling.html)

# %% [markdown]
# # Oversample the minority class

# %%
from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler(random_state=0)

X_resampled, y_resampled = ros.fit_resample(X_train_std, y_train)

from collections import Counter
print(sorted(Counter(y_resampled).items()))
# Out:
# Using TensorFlow backend.
# [(0, 9951), (1, 9951)]

# %% [markdown]
# # Linear Discriminant Analysis

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

param_grid = {'solver': ['lsqr', 'eigen'],
              'shrinkage': [None, 'auto'], 
              'n_components': np.arange(1,5)}

lda_clf = LinearDiscriminantAnalysis()

gs_lda_resamp = GridSearchCV(lda_clf, param_grid=param_grid)

start = time()
gs_lda_resamp.fit(resampled_features, resampled_labels)
lda_duration = time() - start

print("GridSearchCV of LDA took {:.2f} seconds for {} candidate parameter settings.".format(lda_duration, 
                                                                                            len(gs_lda_resamp.cv_results_['params'])))
# report(gs_lda.cv_results_)
print('Optimal solver: {}  Optimal shrinkage: {}  Optimal n_components: {}'.format(gs_lda_resamp.best_params_['solver'], 
                                                                                   gs_lda_resamp.best_params_['shrinkage'], 
                                                                                   gs_lda_resamp.best_params_['n_components']))
print('Accuracy (train): {:.2f}'.format(gs_lda_resamp.score(resampled_features, resampled_labels)))
print('Accuracy  (test): {:.2f}'.format(gs_lda_resamp.score(X_test_std,  y_test)))
# Out:
# GridSearchCV of LDA took 6.67 seconds for 16 candidate parameter settings.
# Optimal solver: lsqr  Optimal shrinkage: auto  Optimal n_components: 1
# Accuracy (train): 0.99
# Accuracy  (test): 0.98

# %% [markdown]
# <a id="statsmodels"></a>

# %% [markdown]
# # [Statsmodels](https://www.statsmodels.org/stable/index.html)

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

# Instantiate the model
logit = sm.Logit(y_train, X_train_std)

# Fit the model
result = logit.fit()

# View the model summary
result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: inf
#          Iterations 9
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 9968
# Model:                          Logit   Df Residuals:                     9939
# Method:                           MLE   Df Model:                           28
# Date:                Thu, 14 May 2020   Pseudo R-squ.:                    -inf
# Time:                        15:24:52   Log-Likelihood:                   -inf
# converged:                       True   LL-Null:                       -125.34
# Covariance Type:            nonrobust   LLR p-value:                     1.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -7.9346      0.139    -57.151      0.000      -8.207      -7.663
# x2             6.8092      0.121     56.123      0.000       6.571       7.047
# x3           -13.6808      0.237    -57.817      0.000     -14.145     -13.217
# x4             7.6140      0.134     56.993      0.000       7.352       7.876
# x5            -8.9805      0.157    -57.067      0.000      -9.289      -8.672
# x6            -2.8432      0.056    -50.669      0.000      -2.953      -2.733
# x7           -15.2424      0.264    -57.753      0.000     -15.760     -14.725
# x8             3.6959      0.070     53.053      0.000       3.559       3.832
# x9            -6.2802      0.111    -56.389      0.000      -6.499      -6.062
# x10          -14.1224      0.245    -57.752      0.000     -14.602     -13.643
# x11            9.4848      0.165     57.371      0.000       9.161       9.809
# x12          -16.6725      0.288    -57.863      0.000     -17.237     -16.108
# x13            0.2105      0.027      7.899      0.000       0.158       0.263
# x14          -16.4009      0.283    -57.880      0.000     -16.956     -15.846
# x15           -0.3514      0.027    -12.913      0.000      -0.405      -0.298
# x16          -13.5705      0.235    -57.723      0.000     -14.031     -13.110
# x17          -23.7609      0.410    -57.984      0.000     -24.564     -22.958
# x18           -8.8383      0.154    -57.254      0.000      -9.141      -8.536
# x19            2.8058      0.055     50.910      0.000       2.698       2.914
# x20            1.5789      0.040     39.721      0.000       1.501       1.657
# x21            1.9319      0.043     44.916      0.000       1.848       2.016
# x22            0.1489      0.027      5.537      0.000       0.096       0.202
# x23           -0.1323      0.030     -4.460      0.000      -0.190      -0.074
# x24           -0.1007      0.026     -3.809      0.000      -0.153      -0.049
# x25            0.3479      0.028     12.301      0.000       0.292       0.403
# x26            0.1086      0.027      4.066      0.000       0.056       0.161
# x27            1.0266      0.034     30.228      0.000       0.960       1.093
# x28            0.3900      0.027     14.318      0.000       0.337       0.443
# x29            0.0102      0.032      0.313      0.754      -0.053       0.074
# ==============================================================================
# """

# %%
# View odds ratios and 95% CIs
# Source: https://www.statsmodels.org/stable/generated/statsmodels.discrete.discrete_model.LogitResults.html
params = result.params

conf = result.conf_int()

conf = pd.DataFrame(conf, columns=['2.5%', '97.5%'])
conf['OR'] = params
conf.columns = ['2.5%', '97.5%', 'OR']

np.exp(conf).round(3)
# Out:
#         2.5%      97.5%         OR
# 0      0.000      0.000      0.000
# 1    714.403   1149.457    906.187
# 2      0.000      0.000      0.000
# 3   1559.600   2632.986   2026.427
# 4      0.000      0.000      0.000
# 5      0.052      0.065      0.058
# 6      0.000      0.000      0.000
# 7     35.141     46.175     40.282
# 8      0.002      0.002      0.002
# 9      0.000      0.000      0.000
# 10  9516.671  18194.141  13158.558
# 11     0.000      0.000      0.000
# 12     1.171      1.300      1.234
# 13     0.000      0.000      0.000
# 14     0.667      0.742      0.704
# 15     0.000      0.000      0.000
# 16     0.000      0.000      0.000
# 17     0.000      0.000      0.000
# 18    14.846     18.426     16.540
# 19     4.486      5.243      4.850
# 20     6.345      7.510      6.903
# 21     1.101      1.223      1.161
# 22     0.827      0.929      0.876
# 23     0.858      0.952      0.904
# 24     1.340      1.497      1.416
# 25     1.058      1.175      1.115
# 26     2.612      2.984      2.791
# 27     1.400      1.558      1.477
# 28     0.948      1.077      1.010

# %%
# View marginal effects of the fitted model
# Source: https://www.statsmodels.org/stable/generated/statsmodels.discrete.discrete_model.LogitResults.html
marginal_effects = result.get_margeff()
marginal_effects.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#         Logit Marginal Effects
# =====================================
# Dep. Variable:                      y
# Method:                          dydx
# At:                           overall
# ==============================================================================
#                 dy/dx    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -1.1504      0.004   -322.373      0.000      -1.157      -1.143
# x2             0.9873      0.005    213.583      0.000       0.978       0.996
# x3            -1.9836      0.003   -567.692      0.000      -1.990      -1.977
# x4             1.1039      0.004    287.015      0.000       1.096       1.111
# x5            -1.3021      0.004   -302.269      0.000      -1.311      -1.294
# x6            -0.4122      0.004   -103.237      0.000      -0.420      -0.404
# x7            -2.2100      0.004   -498.144      0.000      -2.219      -2.201
# x8             0.5359      0.004    129.602      0.000       0.528       0.544
# x9            -0.9106      0.004   -230.466      0.000      -0.918      -0.903
# x10           -2.0476      0.004   -499.718      0.000      -2.056      -2.040
# x11            1.3752      0.004    354.116      0.000       1.368       1.383
# x12           -2.4173      0.004   -585.905      0.000      -2.425      -2.409
# x13            0.0305      0.004      7.973      0.000       0.023       0.038
# x14           -2.3780      0.004   -603.822      0.000      -2.386      -2.370
# x15           -0.0509      0.004    -13.241      0.000      -0.058      -0.043
# x16           -1.9676      0.004   -482.203      0.000      -1.976      -1.960
# x17           -3.4451      0.004   -800.726      0.000      -3.453      -3.437
# x18           -1.2815      0.004   -330.607      0.000      -1.289      -1.274
# x19            0.4068      0.004    105.666      0.000       0.399       0.414
# x20            0.2289      0.004     54.282      0.000       0.221       0.237
# x21            0.2801      0.004     70.664      0.000       0.272       0.288
# x22            0.0216      0.004      5.562      0.000       0.014       0.029
# x23           -0.0192      0.004     -4.474      0.000      -0.028      -0.011
# x24           -0.0146      0.004     -3.817      0.000      -0.022      -0.007
# x25            0.0504      0.004     12.583      0.000       0.043       0.058
# x26            0.0157      0.004      4.076      0.000       0.008       0.023
# x27            0.1488      0.004     35.389      0.000       0.141       0.157
# x28            0.0565      0.004     14.779      0.000       0.049       0.064
# x29            0.0015      0.005      0.313      0.754      -0.008       0.011
# ==============================================================================
# """

# %% [markdown]
# # [Predict](https://www.statsmodels.org/stable/examples/notebooks/generated/predict.html)

# %%
# Make predictions
y_pred = result.predict(X_test_std)
y_pred
# Out:
# array([0.20609537, 0.18693256, 0.21486332, ..., 0.12687692, 0.21070143,
#        0.20863254])

# %%
# Convert predicted probabilities to predicted classes
y_pred_class = np.where(y_pred > 0.50, 1, 0)
y_pred_class
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
print(classification_report(y_test, y_pred_class, 
                            target_names=y_labels))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00      4265
#        Fraud       0.86      0.75      0.80         8
#
#     accuracy                           1.00      4273
#    macro avg       0.93      0.87      0.90      4273
# weighted avg       1.00      1.00      1.00      4273

# %% [markdown]
# [Back to top](#top)
